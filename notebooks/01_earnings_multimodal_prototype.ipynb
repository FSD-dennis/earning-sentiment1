# %% [markdown]
# # Earnings Multimodal Fusion Prototype\n
# \n
# This notebook runs the local CPU-friendly baseline pipeline and inspects outputs.

# %%
from src.earnings_proto.evaluate import run_pipeline\n
\n
run_pipeline()

# %%
import pandas as pd\n
\n
pd.read_csv('reports/classification_metrics.csv').head()
